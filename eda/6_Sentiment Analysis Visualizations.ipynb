# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
neutral = pd.read_csv('../data/neutral.csv')
toxic = pd.read_csv('../data/toxic.csv')

# %%
neutral.columns
# Out:
# Index(['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate',
#        'neutral', 'comment_text', 'cleaner_text', 'compound', 'neg', 'neu',
#        'pos', 'word count', 'character count', 'special characters',
#        'capitalized letters', 'swear words', 'misogynist words',
#        'racial_ethnic slurs', 'lgbtq hate', 'lemmatized_text'],
#       dtype='object')

# %%
toxic.columns
# Out:
# Index(['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate',
#        'neutral', 'comment_text', 'cleaner_text', 'compound', 'neg', 'neu',
#        'pos', 'word count', 'character count', 'special characters',
#        'capitalized letters', 'swear words', 'misogynist words',
#        'racial_ethnic slurs', 'lgbtq hate', 'lemmatized_text'],
#       dtype='object')

# %%
## function to create detailed histograms 

def subplot_histogram(data, axis, mean, title = None, x_label = None, y_label = None, color = None):
    sns.distplot(data, ax = axis, kde = False, hist_kws=dict(edgecolor="k", linewidth=.9, alpha = 0.9), color = color)
    axis.axvline(mean, ls='--', color = 'black', label = f'Mean = {mean}', linewidth = 2)
    axis.set_title(title, pad = 8, fontdict = {'fontsize':14})
    axis.set_xlabel(x_label, labelpad = 6, fontdict = {'fontsize':13})
    axis.set_ylabel(y_label, labelpad = 6, fontdict = {'fontsize':13})
    axis.tick_params(axis = 'both', labelsize = 11)
    axis.legend()
    plt.tight_layout();

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 4))

ax1 = axes[0]
ax2 = axes[1]

subplot_histogram(toxic['neg'], 
                  axis = ax1,
                  mean = toxic['neg'].mean().round(2),
                  title = 'Toxic Corpus',
                  x_label = 'Negative Sentiment Score',
                  y_label = 'Frequency')


subplot_histogram(neutral['neg'], 
                  axis = ax2,
                  mean = neutral['neg'].mean().round(2),
                  title = 'Neutral Corpus',
                  x_label = 'Negative Sentiment Score',
                  y_label = 'Frequency')

plt.suptitle('Negative Sentiment Score Distributions by Corpus', y = 1.12, size = 18);
# Out:
# /Users/heatherrobbins/env3/lib/python3.6/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
len(toxic[toxic['neg'] == 0])
# Out:
# 2405

# %% [markdown]
# This seems weird to me... when looking at the text, some of if it is definitely negative, but has zero negativety score. granted, sentiment analaysis has severe limitations in understanding nuance and context in language, so that can definitely contribute to a 0 score, but still seems odd

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 4))

ax1 = axes[0]
ax2 = axes[1]

subplot_histogram(toxic['pos'], 
                  axis = ax1,
                  mean = toxic['pos'].mean().round(2),
                  title = 'Toxic Corpus',
                  x_label = 'Positive Sentiment Score',
                  y_label = 'Frequency')


subplot_histogram(neutral['pos'], 
                  axis = ax2,
                  mean = neutral['pos'].mean().round(2),
                  title = 'Neutral Corpus',
                  x_label = 'Positive Sentiment Score',
                  y_label = 'Frequency')

plt.suptitle('Positive Sentiment Score Distributions by Corpus', y = 1.12, size = 18);

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 4))

ax1 = axes[0]
ax2 = axes[1]

subplot_histogram(toxic['neu'], 
                  axis = ax1,
                  mean = toxic['neu'].mean().round(2),
                  title = 'Toxic Corpus',
                  x_label = 'Sentiment Score',
                  y_label = 'Frequency')


subplot_histogram(neutral['neu'], 
                  axis = ax2,
                  mean = neutral['neu'].mean().round(2),
                  title = 'Neutral Corpus',
                  x_label = 'Sentiment Score',
                  y_label = 'Frequency')

plt.suptitle('Neutral Sentiment Score Distributions by Corpus', y = 1.12, size = 18);

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 4))

ax1 = axes[0]
ax2 = axes[1]

subplot_histogram(toxic['compound'], 
                  axis = ax1,
                  mean = toxic['compound'].mean().round(2),
                  title = 'Toxic Corpus',
                  x_label = 'Sentiment Score',
                  y_label = 'Frequency')


subplot_histogram(neutral['compound'], 
                  axis = ax2,
                  mean = neutral['compound'].mean().round(2),
                  title = 'Neutral Corpus',
                  x_label = 'Sentiment Score',
                  y_label = 'Frequency')

plt.suptitle('Compound Sentiment Score Distributions by Corpus', y = 1.12, size = 18)
plt.savefig("Compound_sentiment.png", dpi=300, bbox_inches="tight")
